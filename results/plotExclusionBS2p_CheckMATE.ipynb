# %%
import matplotlib.pyplot as plt
import os,glob
import numpy as np
import seaborn as sns
from scipy.special import kn,zetac
import copy
import mypyslha as pyslha
from addCombinedLimit import getCombinedR, CovarianceHandler
sns.set() #Set style
sns.set_style('ticks',{'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
sns.set_palette(sns.color_palette("Paired"))

# %%
def getContour(xpts,ypts,zpts,levels):
    """
    Uses pyplot tricontour method to obtain contour
    curves in a 2D plane.

    :return: A dictionary with a list of contours for each level
    """
    
    fig = plt.figure()
    x = copy.deepcopy(xpts)
    y = copy.deepcopy(ypts)
    z = copy.deepcopy(zpts)
    CS = plt.tricontour(x,y,z,levels=levels)    
    levelPts = {}
    for il,level in enumerate(CS.levels):
        levelPts[level] = []
        c = CS.collections[il]        
        paths = c.get_paths()
        for path in paths:
            levelPts[level].append(path.vertices)
    plt.close(fig)
    
    return levelPts

# %% [markdown]
# ## Get CheckMate Output

# %%
resultFolder = '../data/checkmate_BS2p'
slhaFolder = '../data/slha_BS2p'
recastDataByAna = {'cms_sus_16_048' : [],
              'cms_sus_16_025' : [],
              'atlas_conf_2016_054' : [],
              'atlas_susy_2018_04' : [],
              'cms_sus_19_005' : [], 'cms_sus_16_032' : [], 
              'atlas_conf_2019_040' : [], 'atlas_conf_2019_018' : [], 
               'atlas_exot_2018_06' : []}
usedAnalyses = ['cms_sus_16_032']
usedAnalyses = 'all'
recastData = []
lambdaL = []
lambdaR = []
mLQ = []

kfactor = 1.5

for slhaFile in glob.glob(slhaFolder+'/*.slha'):
    slhaData = pyslha.readSLHAFile(slhaFile)
    mchi = slhaData.blocks['MASS'][5000521]
    mlsp = slhaData.blocks['MASS'][5000522]
    mLQ.append(slhaData.blocks['MASS'][42])
    lambdaL.append(slhaData.blocks['LQLAML'][(3,3)])
    lambdaR.append(slhaData.blocks['LQLAMR'][(2,3)])
    resDir = os.path.splitext(os.path.basename(slhaFile))[0]
    resFile = os.path.join(resultFolder,resDir,'evaluation',
                'total_results.txt')
    if not os.path.isfile(resFile):
        continue
    data = np.genfromtxt(resFile,names=True,
            dtype=None,encoding=None)

    ibest = np.argmax(data['rexp'])
    bestAna = data['analysis'][ibest]    
    robs = kfactor*data['robscons'][ibest]    
#     robs = kfactor*data['robs'][ibest]    
    if not bestAna in recastDataByAna:
        print(bestAna,'not in recastData')    
    for ana in recastDataByAna:
        dataAna = [pt for pt in data if pt['analysis'] == ana]
        ibestAna = np.argmax([pt['rexp'] for pt in dataAna])
        robsAna = [kfactor*pt['robscons'] for pt in dataAna][ibestAna]
#         robsAna = [kfactor*pt['robs'] for pt in dataAna][ibestAna]
        recastDataByAna[ana].append([mchi,mlsp,robsAna])        
    if usedAnalyses != 'all':
        robs = 0.0
        for ana in usedAnalyses:
            robs = max(robs,recastDataByAna[ana][-1][-1])
    recastData.append([mchi,mlsp,robs])
        
for key,val in recastDataByAna.items():
    recastDataByAna[key] = np.array(val)
recastData = np.array(recastData)

if len(set(mLQ)) != 1:
    print('Multiple leptoquark masses found')
else:
    mLQ = mLQ[0]
if len(set(lambdaR)) != 1:
    print('Multiple values for lambdaR found')
else:
    lambdaR = lambdaR[0]    
if len(set(lambdaL)) != 1:
    print('Multiple values for lambdaL found')
else:
    lambdaL = lambdaL[0]

# %%
contoursByAna = dict([[ana,getContour(recastD[:,0],recastD[:,0]-recastD[:,1],recastD[:,2],levels=[1.0])] 
                      for ana,recastD in recastDataByAna.items()])

# %% [markdown]
# ## Plot Curves

# %%
fig, axes = plt.subplots(nrows=int(len(recastDataByAna)/2.)+1, ncols=2, figsize=(18,18))
irow = 0
icolumn = 0
for ana,rData in recastDataByAna.items():
    ax = axes[irow,icolumn]
    im = ax.scatter(rData[:,0],rData[:,0]-rData[:,1],c=rData[:,2],
                    s=35,cmap=plt.cm.get_cmap('RdYlBu'), vmin=0., vmax=2.)
    for level,curves in contoursByAna[ana].items():
        if level != 1.0: continue
        for i,curve in enumerate(curves):
            if i == 0:
                ax.plot(curve[:,0],curve[:,1],label=ana,
                    linestyle='--',linewidth=4)
            else:
                ax.plot(curve[:,0],curve[:,1],
                    linestyle='--',linewidth=4)
                
    ax.set_title(r"$\chi_1 + \bar{\chi}_1 \to c \tau \chi_0 + c \tau \chi_0$ (%s)" %ana,fontsize=15)
    ax.set_xlabel(r'$m_{\chi_1}$ (GeV)')    
    ax.set_ylabel(r'$m_{\chi_1}-m_{\chi_0}$ (GeV)')
    ax.set_ylim(0.,25.)
#     ax.legend()
    icolumn += 1
    if icolumn >= 2:
#         cb = fig.colorbar(im, ax=axes[irow,:].ravel().tolist())
        irow += 1 
        icolumn = 0
             
plt.subplots_adjust(hspace=0.5, wspace=0.2, right=0.8)
cb = fig.colorbar(im, ax=axes[:,:].ravel().tolist())
# plt.tight_layout()
# plt.savefig('TSbottom_exclusion_BM2.png')
plt.show()

# %%
#Curve from LH proceedings figure
monoJet = np.loadtxt('jets_plus_met_mchi1_vs_delta.csv',delimiter=',',skiprows=1)

# %%
fig = plt.figure(figsize=(14,8))
for ana,c in contoursByAna.items():
    if usedAnalyses != 'all' and not ana in usedAnalyses:
        alpha = 0.2
    else:
        alpha = 1.0
    for level,curves in c.items():
        if level != 1.0: continue
        for i,curve in enumerate(sorted(curves, key = lambda c: len(c),reverse=True)):
            if i == 0:
                plt.plot(curve[:,0],curve[:,1],label=ana,
                    linewidth=4,alpha=alpha)
            else:
                continue
                plt.plot(curve[:,0],curve[:,1],
                    linewidth=4,alpha=alpha)
plt.plot(monoJet[:,0],monoJet[:,1],linestyle='--',label='mono jet (LH proceedings)',linewidth=4,alpha=0.2)
plt.title(r"$\chi_1 + \bar{\chi}_1 \to c \tau \chi_0 + c \tau \chi_0$ (CheckMATE)",fontsize=15)

plt.title(r"$\chi_1 + \bar{\chi}_1 \to c \tau \chi_0 + c \tau \chi_0$, "
          +r"$\left(\lambda_L\right)_{33} = %1.3f, \left(\lambda_R\right)_{23} = %1.3f, m_{S_1} = %1.2f$ TeV (CheckMATE)"
          %(lambdaL,lambdaR,mLQ/1000.0) ,fontsize=15)


# plt.text(850.,70.,r"$m_{S_1} = %1.2f$ TeV"%(mLQ/1000.)+"\n" +r"$\left(\lambda_R\right)_{23} = %1.3f$"%(lambdaR)
#          +"\n" + r"$\left(\lambda_L\right)_{33} = %1.3f$" %(lambdaL),fontsize=15)
plt.xlim(400.,1000.)
plt.ylim(0,300.)
plt.xlabel(r'$m_{\chi_1}$ (GeV)')    
plt.ylabel(r'$m_{\chi_1}-m_{\chi_0}$ (GeV)')
plt.legend(loc=(0.9,0.55),framealpha=1.0)
plt.xticks(np.arange(400.,1000.,50.))
plt.grid()
plt.tight_layout()
# plt.savefig('BS1p_exclusionAll.png')
plt.show()

# %%
#Trim data to get smooth curve
recastDataTrim = []
for pt in recastData:
    if pt[0]-pt[1] in np.arange(0.,260.,20.) or pt[0]-pt[1] < 10.0:
        recastDataTrim.append(pt)
recastDataTrim = np.array(recastDataTrim)
contoursTrim = getContour(recastDataTrim[:,0],recastDataTrim[:,0]-recastDataTrim[:,1],recastDataTrim[:,2],levels=[1.0])
contours = getContour(recastData[:,0],recastData[:,0]-recastData[:,1],recastData[:,2],levels=[1.0])

# %%
fig = plt.figure(figsize=(12,8))
cp = plt.scatter(recastData[:,0],recastData[:,0]-recastData[:,1],c=recastData[:,2],
                    s=35,cmap=plt.cm.get_cmap('RdYlBu'), vmin=0., vmax=2.)
   
excCurveTrim =  sorted(contoursTrim[1.0], key = lambda pt: len(pt), reverse=True)[0]
excCurve =  sorted(contours[1.0], key = lambda pt: len(pt), reverse=True)[0]
plt.plot(excCurveTrim[:,0],excCurveTrim[:,1],label='Exclusion',
                linestyle='-',linewidth=4)
plt.fill_betweenx(excCurveTrim[:,1],recastData[:,0].min(),excCurveTrim[:,0],alpha=0.5)

# plt.plot(excCurve[:,0],excCurve[:,1],label='Exclusion',
#                 linestyle='-',linewidth=4)


# plt.fill_between(excCurve[:,0],excCurve[:,1],excCurve[:,1].max(),alpha=0.5)
cb = plt.colorbar(cp)
# plt.yscale('log')
plt.xlabel(r'$m_{\chi_1}$ (GeV)')    
plt.ylabel(r'$m_{\chi_1}-m_{\chi_0}$ (GeV)')
# plt.xlim(200.,1500.)
plt.ylim(5,200.)
plt.legend()
plt.tight_layout()
plt.title(r"$\chi_1 + \bar{\chi}_1 \to b \nu_\tau \chi_0 + b \nu_\tau \chi_0$, "
          +r"$\left(\lambda_L\right)_{33} = %1.3f, \left(\lambda_R\right)_{23} = %1.3f, m_{S_1} = %1.2f$ TeV (CheckMATE)"
          %(lambdaL,lambdaR,mLQ/1000.0) ,fontsize=15)
plt.tight_layout()
# plt.savefig('exclusion_BS1p.png')
plt.show()

# %%
header = 'lambdaL33 = %1.3f, lambdaR23 = %1.3f, mLQ = %1.2f' %(lambdaL,lambdaR,mLQ)
header += '\n mchi1 (GeV), mchi1-mchi0 (GeV)'
np.savetxt('BS2p_exclusion_CheckMATE.txt',excCurve,delimiter=',',header=header)

# %%
excCurveTrim[:,0].max()
# Out:
# 801.6434765073603
