# %%
import os,sys,glob
smodelsPath = os.path.expanduser('~/smodels')
sys.path.append(smodelsPath)
from smodels.theory.auxiliaryFunctions import rescaleWidth, unscaleWidth
import numpy as np
from trimRegularGrid import trim1D, testTrimmedGrid, removeWidth

# %% [markdown]
# ### Trim data along width dimension

# %%
maxDiff=5e-2
minValue=1e-8
datasetNames = ['SR2FULL_150','SR2FULL_350','SR2FULL_575','SR2FULL_800', 
                'SR1FULL_175', 'SR1FULL_375', 'SR1FULL_600', 'SR1FULL_825']
txNames = ['THSCPM1b','THSCPM2b','THSCPM3','THSCPM4','THSCPM5', 'THSCPM6','THSCPM7','THSCPM8','THSCPM9']
zlabel = 'width'

for tx in txNames:
    for ds in datasetNames:
        dataFile = '%s_eff_mutrig_%s.dat' %(tx,ds)
        print('\n',dataFile)
        valueLabel = ds
        #Get data
        data = np.genfromtxt(dataFile,names=True)
        xlabels = [x for x in data.dtype.names if not 'ctau' in x.lower() and not x == valueLabel and not x == zlabel]
        xpts = [list(x) for x in data[xlabels]]
        ypts = data[valueLabel]
        zpts = [rescaleWidth(z) for z in data[zlabel]]
        data[zlabel] = np.array(zpts)
        keepLines = trim1D(zpts,xpts,ypts,maxDiff=maxDiff,minY=minValue)

        #Check Interpolation
        newData = data[keepLines]
        data_trim = [list(x) for x in newData[xlabels+[zlabel,valueLabel]]]
        data_full = [list(x) for x in data[xlabels+[zlabel,valueLabel]]]

        #Save trimmed grid to file:
        data = np.genfromtxt(dataFile,names=True)  #Get original data
        newF = os.path.splitext(dataFile)[0]+'_trimmedwidth.dat'
        header = '%19s'*len(data.dtype.names) %data.dtype.names
        header = header[3:]
        newData = data[keepLines]
        np.savetxt(newF,newData,header=header,fmt = ['     %1.7e']*len(data.dtype.names))
# Out:
#  THSCPM1b_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 38% (584/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 33% (512/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 28% (433/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 25% (382/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 36% (553/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 32% (486/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 27% (417/1536) in 0.0 min
#
#  THSCPM1b_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 24% (363/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 6% (96/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 6% (96/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 6% (96/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 6% (96/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 34% (518/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 30% (457/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 26% (394/1536) in 0.0 min
#
#  THSCPM2b_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 23% (350/1536) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 37% (6476/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 33% (5753/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 28% (4941/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 24% (4193/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 35% (6164/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 31% (5506/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 28% (4848/17568) in 0.0 min
#
#  THSCPM3_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 24% (4219/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 34% (5998/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 31% (5367/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 27% (4724/17568) in 0.0 min
#
#  THSCPM4_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 24% (4130/17568) in 0.0 min
#
#  THSCPM5_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 39% (33266/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 35% (29249/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 30% (24875/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 25% (20917/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 38% (32119/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 34% (28404/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 29% (24655/84256) in 0.1 min
#
#  THSCPM5_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 25% (21188/84256) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 6% (5734/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 6% (5734/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 6% (5734/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 6% (5734/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 34% (31192/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 30% (27660/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 26% (24051/91744) in 0.1 min
#
#  THSCPM6_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 23% (20822/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 37% (34078/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 33% (30083/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 28% (25724/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 24% (21705/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 36% (33117/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 32% (29393/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 28% (25546/91744) in 0.1 min
#
#  THSCPM7_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 24% (22073/91744) in 0.1 min
#
#  THSCPM8_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 37% (6481/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 33% (5746/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 28% (4930/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 24% (4190/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 36% (6269/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 32% (5579/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 28% (4894/17568) in 0.0 min
#
#  THSCPM8_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 24% (4247/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR2FULL_150.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR2FULL_350.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR2FULL_575.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR2FULL_800.dat
# Data successfully trimmed down to 6% (1098/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR1FULL_175.dat
# Data successfully trimmed down to 34% (6047/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR1FULL_375.dat
# Data successfully trimmed down to 31% (5408/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR1FULL_600.dat
# Data successfully trimmed down to 27% (4745/17568) in 0.0 min
#
#  THSCPM9_eff_mutrig_SR1FULL_825.dat
# Data successfully trimmed down to 24% (4153/17568) in 0.0 min

# %% [markdown]
# ### Remove width data from 4D maps:

# %%
datasetNames = ['SR2FULL_150','SR2FULL_350','SR2FULL_575','SR2FULL_800', 
                'SR1FULL_175', 'SR1FULL_375', 'SR1FULL_600', 'SR1FULL_825']
txNames = ['THSCPM5', 'THSCPM6','THSCPM7']

for tx in txNames:
    for ds in datasetNames:
        dataFile = '%s_eff_mutrig_%s.dat' %(tx,ds)
        print('\n',dataFile)
        #Get data
        data = np.genfromtxt(dataFile,names=True)
        #Remove width
        reducedData = removeWidth(data)
    
    
        newF = os.path.splitext(dataFile)[0]+'_noWidth.dat'
        header = '%19s'*len(data.dtype.names) %data.dtype.names
        header = header[3:]
        np.savetxt(newF,reducedData,header=header,fmt = ['     %1.7e']*len(data.dtype.names))
# Out:
#  THSCPM5_eff_mutrig_SR2FULL_150.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR2FULL_350.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR2FULL_575.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR2FULL_800.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR1FULL_175.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR1FULL_375.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR1FULL_600.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM5_eff_mutrig_SR1FULL_825.dat
# Removing widths reduced data down to 3% (2633/84256)
#
#  THSCPM6_eff_mutrig_SR2FULL_150.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR2FULL_350.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR2FULL_575.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR2FULL_800.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR1FULL_175.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR1FULL_375.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR1FULL_600.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM6_eff_mutrig_SR1FULL_825.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR2FULL_150.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR2FULL_350.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR2FULL_575.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR2FULL_800.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR1FULL_175.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR1FULL_375.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR1FULL_600.dat
# Removing widths reduced data down to 3% (2867/91744)
#
#  THSCPM7_eff_mutrig_SR1FULL_825.dat
# Removing widths reduced data down to 3% (2867/91744)
